# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/df_merge_singkat.csv')
df.head()
df.describe()
# Out:
#        Luas_Hutan_ha  Jumlah_Emisi_2018  Jumlah_Emisi_2019  Jumlah_Emisi_2020  \
# count   3.300000e+01       3.300000e+01       3.300000e+01       3.300000e+01
# mean    4.871445e+06       4.925906e+06       1.888034e+07       1.210152e+06
# std     5.843812e+06       1.119043e+07       4.743872e+07       2.402171e+06
# min     9.107727e+03       0.000000e+00       0.000000e+00       0.000000e+00
# 25%     1.313230e+06       3.675200e+04       2.815200e+05       3.057600e+04
# 50%     3.130946e+06       5.065430e+05       8.850180e+05       2.531080e+05
# 75%     5.503841e+06       2.557810e+06       6.646052e+06       1.623911e+06
# max     2.787490e+07       4.355416e+07       2.161338e+08       1.242300e+07
#
#        Jumlah_Emisi_2021  Jumlah_Emisi_2022  jumlah_Kebakaran_Hutan_2018  \
# count       3.300000e+01       3.300000e+01                    33.000000
# mean        1.399890e+06       7.118399e+05                 16019.361515
# std         3.051293e+06       1.395136e+06                 26607.325097
# min         0.000000e+00       0.000000e+00                     0.000000
# 25%         1.095200e+04       1.953700e+04                   331.670000
# 50%         1.627700e+05       1.605070e+05                  2421.900000
# 75%         1.028498e+06       8.584240e+05                 15156.220000
# max         1.465201e+07       6.936347e+06                 98637.990000
#
#        jumlah_Kebakaran_Hutan_2019  jumlah_Kebakaran_Hutan_2020  \
# count                    33.000000                    33.000000
# mean                  49718.151515                  8946.090909
# std                   84507.158138                 20585.732285
# min                       0.000000                     0.000000
# 25%                    2133.000000                   569.000000
# 50%                    9552.000000                  2344.000000
# 75%                   60234.000000                  7646.000000
# max                  336798.000000                114719.000000
#
#        jumlah_Kebakaran_Hutan_2021  jumlah_Kebakaran_Hutan_2022
# count                    33.000000                    33.000000
# mean                  10823.909091                  6197.696970
# std                   28814.354352                 13391.834288
# min                       0.000000                     0.000000
# 25%                     385.000000                   328.000000
# 50%                    1588.000000                  1620.000000
# 75%                    5411.000000                  4915.000000
# max                  137343.000000                 70637.000000

# %%
# 2. Load dataset
df = pd.read_csv('/content/df_merge_singkat.csv')

# 3. Simpan nama provinsi, lalu hapus untuk proses clustering
provinsi = df['Provinsi']
X = df.drop(columns=['Provinsi'])

# 4. Standardisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 5. KMeans clustering (jumlah cluster = 3)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

# 6. Tambahkan hasil cluster ke DataFrame
df['Cluster'] = clusters

# 7. Hitung rata-rata tiap fitur per cluster
cluster_mean = df.drop(columns=['Provinsi'], errors='ignore').groupby('Cluster').mean()

# 8. Hitung total emisi & kebakaran per cluster
emisi_cols = ['Jumlah_Emisi_2018', 'Jumlah_Emisi_2019', 'Jumlah_Emisi_2020',
              'Jumlah_Emisi_2021', 'Jumlah_Emisi_2022']
kebakaran_cols = ['jumlah_Kebakaran_Hutan_2018', 'jumlah_Kebakaran_Hutan_2019',
                  'jumlah_Kebakaran_Hutan_2020', 'jumlah_Kebakaran_Hutan_2021',
                  'jumlah_Kebakaran_Hutan_2022']

cluster_mean['Total_Emisi'] = cluster_mean[emisi_cols].sum(axis=1)
cluster_mean['Total_Kebakaran'] = cluster_mean[kebakaran_cols].sum(axis=1)

# 9. Skor Gabungan
cluster_mean['Skor_Gabungan'] = cluster_mean['Total_Emisi'] + cluster_mean['Total_Kebakaran']

# 10. Mapping cluster ke kategori berdasarkan urutan Skor Gabungan
sorted_clusters = cluster_mean['Skor_Gabungan'].sort_values().index
label_map = {
    sorted_clusters[0]: 'Rendah',
    sorted_clusters[1]: 'Sedang',
    sorted_clusters[2]: 'Tinggi'
}
df['Kategori'] = df['Cluster'].map(label_map)

# 11. Visualisasi hasil clustering dengan PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

df_viz = pd.DataFrame(X_pca, columns=['PCA1', 'PCA2'])
df_viz['Kategori'] = df['Kategori']
df_viz['Provinsi'] = df['Provinsi']

plt.figure(figsize=(10, 7))
sns.scatterplot(data=df_viz, x='PCA1', y='PCA2', hue='Kategori', palette='Set2', s=100)
for i in range(len(df_viz)):
    plt.text(df_viz['PCA1'][i]+0.05, df_viz['PCA2'][i]+0.05, df_viz['Provinsi'][i], fontsize=8)
plt.title('Clustering Provinsi Berdasarkan Emisi & Kebakaran (KMeans)')
plt.grid(True)
plt.show()

# 12. Tampilkan hasil
print("=== Hasil Kategori ===")
print(df[['Provinsi', 'Cluster', 'Kategori']])
# Out:
# === Hasil Kategori ===
#                      Provinsi  Cluster Kategori
# 0                      MALUKU        0   Rendah
# 1                MALUKU UTARA        0   Rendah
# 2   KEPULAUAN BANGKA BELITUNG        0   Rendah
# 3                      BANTEN        0   Rendah
# 4                   GORONTALO        0   Rendah
# 5                 PAPUA BARAT        0   Rendah
# 6                  JAWA BARAT        0   Rendah
# 7                       PAPUA        0   Rendah
# 8              SULAWESI UTARA        0   Rendah
# 9            SUMATERA SELATAN        0   Rendah
# 10             KEPULAUAN RIAU        0   Rendah
# 11                       RIAU        1   Tinggi
# 12             SULAWESI BARAT        0   Rendah
# 13           SULAWESI SELATAN        0   Rendah
# 14                       ACEH        0   Rendah
# 15                       BALI        0   Rendah
# 16                   BENGKULU        0   Rendah
# 17              DI YOGYAKARTA        0   Rendah
# 18                DKI JAKARTA        0   Rendah
# 19                      JAMBI        0   Rendah
# 20                JAWA TENGAH        0   Rendah
# 21                 JAWA TIMUR        0   Rendah
# 22           KALIMANTAN BARAT        1   Tinggi
# 23         KALIMANTAN SELATAN        0   Rendah
# 24          KALIMANTAN TENGAH        1   Tinggi
# 25           KALIMANTAN TIMUR        0   Rendah
# 26                    LAMPUNG        0   Rendah
# 27        NUSA TENGGARA BARAT        2   Sedang
# 28        NUSA TENGGARA TIMUR        2   Sedang
# 29            SULAWESI TENGAH        0   Rendah
# 30          SULAWESI TENGGARA        0   Rendah
# 31             SUMATERA BARAT        0   Rendah
# 32             SUMATERA UTARA        0   Rendah

# %%
# 1. Fitur yang dipakai
features = [
    'Luas_Hutan_ha',
    'jumlah_Kebakaran_Hutan_2018', 'jumlah_Kebakaran_Hutan_2019',
    'jumlah_Kebakaran_Hutan_2020', 'jumlah_Kebakaran_Hutan_2021',
    'jumlah_Kebakaran_Hutan_2022',
    'Jumlah_Emisi_2018', 'Jumlah_Emisi_2019',
    'Jumlah_Emisi_2020', 'Jumlah_Emisi_2021',
    'Jumlah_Emisi_2022'
]
X = df[features]

# 2. Normalisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Clustering KMeans
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# 4. Hitung total emisi & total kebakaran per provinsi
df['Total_Emisi'] = df[['Jumlah_Emisi_2018', 'Jumlah_Emisi_2019', 'Jumlah_Emisi_2020',
                        'Jumlah_Emisi_2021', 'Jumlah_Emisi_2022']].sum(axis=1)

df['Total_Kebakaran'] = df[['jumlah_Kebakaran_Hutan_2018', 'jumlah_Kebakaran_Hutan_2019',
                            'jumlah_Kebakaran_Hutan_2020', 'jumlah_Kebakaran_Hutan_2021',
                            'jumlah_Kebakaran_Hutan_2022']].sum(axis=1)

# 5. Tentukan kategori kebakaran berdasarkan rata-rata tiap cluster
cluster_kebakaran_avg = df.groupby('Cluster')['Total_Kebakaran'].mean().sort_values()
cluster_labels_kebakaran = {
    cluster_kebakaran_avg.index[0]: 'Rendah',
    cluster_kebakaran_avg.index[1]: 'Sedang',
    cluster_kebakaran_avg.index[2]: 'Tinggi'
}
df['Kategori_Kebakaran'] = df['Cluster'].map(cluster_labels_kebakaran)

# 6. Gunakan kategori kebakaran sebagai dasar kategori emisi akhir
df['Kategori_Emisi'] = df['Kategori_Kebakaran']

# 7. Visualisasi PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
df['PCA1'] = X_pca[:, 0]
df['PCA2'] = X_pca[:, 1]

plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x='PCA1', y='PCA2', hue='Kategori_Emisi', palette='viridis', s=100)
for i in range(len(df)):
    plt.text(df['PCA1'][i], df['PCA2'][i], df['Provinsi'][i], fontsize=8)
plt.title("Kategori Emisi Berdasarkan Kebakaran (KMeans Clustering)")
plt.legend(title='Kategori Emisi')
plt.grid(True)
plt.tight_layout()
plt.show()

# 8. Tampilkan hasil akhir
print(df[['Provinsi', 'Kategori_Emisi', 'Total_Emisi', 'Total_Kebakaran']])
# Out:
#                      Provinsi Kategori_Emisi  Total_Emisi  Total_Kebakaran
# 0                      MALUKU         Rendah      7020795         89148.44
# 1                MALUKU UTARA         Rendah       279160          3188.54
# 2   KEPULAUAN BANGKA BELITUNG         Rendah      1620576          8122.67
# 3                      BANTEN         Rendah         2557            11.00
# 4                   GORONTALO         Rendah       223929          2411.65
# 5                 PAPUA BARAT         Rendah      4165853          9573.50
# 6                  JAWA BARAT         Rendah      1536838         19304.51
# 7                       PAPUA         Rendah     15561003        249328.84
# 8              SULAWESI UTARA         Rendah       371185          6125.39
# 9            SUMATERA SELATAN         Rendah    163876994        362942.60
# 10             KEPULAUAN RIAU         Rendah      1455839         16870.96
# 11                       RIAU         Sedang    133224812        157113.27
# 12             SULAWESI BARAT         Rendah       341443          5950.38
# 13           SULAWESI SELATAN         Rendah      1124010         21253.27
# 14                       ACEH         Rendah      2779357          8075.70
# 15                       BALI         Rendah        95299          1418.76
# 16                   BENGKULU         Rendah       328249          1953.82
# 17              DI YOGYAKARTA         Rendah         5543           204.00
# 18                DKI JAKARTA         Rendah            0             0.00
# 19                      JAMBI         Rendah     31389820         60630.75
# 20                JAWA TENGAH         Rendah       692568         13335.67
# 21                 JAWA TIMUR         Rendah      9466578         69527.39
# 22           KALIMANTAN BARAT         Sedang    138944460        270413.03
# 23         KALIMANTAN SELATAN         Rendah     37015923        249556.99
# 24          KALIMANTAN TENGAH         Sedang    253699047        378069.57
# 25           KALIMANTAN TIMUR         Rendah     21163094        105040.20
# 26                    LAMPUNG         Rendah     10723367         65460.22
# 27        NUSA TENGGARA BARAT         Tinggi     12519492        235592.38
# 28        NUSA TENGGARA TIMUR         Tinggi     26091010        517047.79
# 29            SULAWESI TENGAH         Rendah      1869096         25090.28
# 30          SULAWESI TENGGARA         Rendah      2791689         33951.67
# 31             SUMATERA BARAT         Rendah      8211699         18027.90
# 32             SUMATERA UTARA         Rendah      6637031         21530.79
